# %% [markdown]
# # Analisi Dataset Dummy #

# %% [markdown]
# #### Libraries Import ####

# %%
import pandas as pd
from langdetect import detect
from IPython.display import display
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
import re
from numpy import mean
from sklearn import metrics


import nltk
import os
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
nltk.download('punkt')
nltk.download('omw-1.4')

from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_validate
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split





from sklearn.model_selection import GridSearchCV

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import make_scorer, roc_curve, roc_auc_score
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
# Out:
# [nltk_data] Downloading package stopwords to /home/paolo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/paolo/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /home/paolo/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/paolo/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# #### DataSet Reading ####

# %%
path_to_dataset = os.path.join('Files_to_process', 'news_dataset.csv') # Generate the path where the dataset has to be

df = pd.read_csv("~/Files_to_process/news_dataset.csv", sep='___', engine='python')

# %%
df.shape
# Out:
# (3924, 4)

# %%
pd.set_option('display.max_rows', None)
df['news']
# Out:
# 0       Così le varianti Covid sono entrate nell’osped...
# 1       La certezza è arrivata ieri pomeriggio: il vir...
# 2       Ancona, 8 febbraio 2021 - Casi positivi alla v...
# 3       Bologna, 4 febbraio 2021 - Scoperti casi di va...
# 4       Bologna, 6 febbraio 2021 - Sei casi di variant...
# 5       BOLOGNA. Le varianti del Covid sono ormai tra ...
# 6       Una situazione che viene definita «sotto contr...
# 7       Coronavirus: a Brescia un positivo su cinque è...
# 8       Ormai è quasi certo: la variante brasiliana, q...
# 9       Primi due casi di variante brasiliana accertat...
# 10      È arrivata in Italia anche la variante Sudafri...
# 22      E sono risultati tutti negativi al primo test ...
# 23      Primi contagiati in Italia. "Sono sei i casi d...
# 24      Sono saliti a 163 i pazienti in Toscana a cui ...
# 25      Proseguono le segnalazioni in Italia delle tre...
# 26      La metà dei casi di coronavirus accertati tra ...
# 27      "Cari concittadini, siamo costretti a malincuo...
# 28      Si spengono le luci e pure le campanelle per u...
# 29      La Variante inglese sarebbe arrivata anche a C...
# 30      Primi due casi di variante inglese del Covid-1...
# 31      Variante inglese: accertati cinque casi nel Br...
# 32      Dove sono state chiuse le scuole per impennata...
# 33      Urbania (Pesaro Urbino), 12 febbraio 2021 - Du...
# 34      Ad allarmare l’autorità sanitaria è soprattutt...
# 35      Nonostante nel Municipio XV gli incrementi set...
# 36      I risultati di laboratorio hanno confermato i ...
# 37      ROVIGO Tipizzata la variante inglese anche in ...
# 38      Genova. La variante inglese in Liguria pesa “p...
# 39      Coronavirus: focolaio di variante inglese a Gu...
# 40      L’Istituto Zooprofilattico ha isolato la mutaz...
# 41      I focolai di Covid 19 con la variante inglese ...
# 42      Non coinvolge la proteina Spike e quindi non i...
# 43      Aumentano i contagi di Covid-19 in Italia. Son...
# 44      Oltre 300 studenti italiani minorenni sono att...
# 45      Hanno soggiornato in Toscana (tra Firenze, Pis...
# 46      In Salento Coronavirus, caso sospetto su donna...
# 47      Sette persone della provincia di Ravenna sono ...
# 48      CREMONA (10 febbraio 2020) - Sono 25 mila - se...
# 49      Identificata per la prima volta in Emilia-Roma...
# 50         Le reinfezioni da Covid-19 sono in aumento ...
# 51      SIRACUSA - Un cinese residente a Siracusa con ...
# 52      Migliorano giorno dopo giorno le condizioni de...
# 53      Due casi sospetti di a Battipaglia e anche a S...
# 54      EVENTO: L’Azienda Usl di Piacenza informa che ...
# 55      Si aggravano le condizioni della coppia di Wuh...
# 56      Due turiste cinesi sono state ricoverate quest...
# 57      Scabbia umana all’asilo: con un bimbo infettat...
# 58      In un controllo alle scuole di Camaiore, predi...
# 59      Da oggi, lunedì 7 febbraio, le Marche passano ...
# 60      La nuova variante Omicron 2 è arrivata anche i...
# 61      Ancona, 31 gennaio 2022 - Dopo essere stata is...
# 62      La variante Covid Omicron 2 è arrivata anche i...
# 63      "La variante Omicron 2 è stata individuata in ...
# 64      La variante Omicron 3 del Coronavirus arriva i...
# 65      In Italia c'è una nuova sotto-variante di Omic...
# 66      In Italia, nel flash survey dell'Istituto supe...
# 67      La provincia di Ancona, 4 comuni in provincia ...
# 68      Viggiù, 5230 abitanti in provincia di Varese. ...
# 69      Dopo il primo caso accertato a Napoli a metà f...
# 70      In Alto Adige continua l'emergenza Coronavirus...
# 71      Isolata in Lombardia una nuova (e rarissima) v...
# 72      In tutta Italia aumentano le segnalazioni di c...
# 73      Continua a circolare la variante britannica de...
# 74      L’Italia si colora sempre più di rosso. Da lun...
# 75      Coronavirus, l'Ordine dei medici di Firenze: “...
# 76      È arrivata la conferma dal laboratorio di Cata...
# 77      Ascoli - Grazie all’efficiente tracciamento de...
# 78      Prosegue il monitoraggio delle varianti del co...
# 79      Come in un cortocircuito, saranno feste di luc...
# 80      TRIESTE Omicron "sbarca" in Friuli Venezia Giu...
# 81      Sette casi di contagio da variante Omicron in ...
# 82      Firenze, 19 dicembre 2021 - Esplode Omicron an...
# 83      ISS 18 dicembre 2021 Sono salite a 84 le seque...
# 84      Il ministro della Salute Roberto Speranza ha f...
# 85      Per quanti il numero dei contagi sia iniziato ...
# 86      La presenta delle varianti del SARS-CoV-2 in I...
# 87      Coronavirus, primo caso di variante brasiliana...
# 88      Si allarga il cluster dei positivi al Covid in...
# 89       In Italia, dove il tasso di positività è stab...
# 90      Omicron BA.2.12.1 approda anche nelle Marche. ...
# 91      In Sicilia, per ultimo, è stato individuato un...
# 92      In Veneto fanno capolino due nuove varianti de...
# 93      PIEMONTE- 10-05-2022--Dai dati diffusi da Arpa...
# 94      MATERA – In tre giorni, da venerdì 23 a domeni...
# 95      FIRENZE. Quasi un positivo su cinque si infett...
# 96      ﻿«Ho ricevuto dal Seresmi-Spallanzani (servizi...
# 97      Nella tarda serata di martedì, da Roma, è arri...
# 98      La variante Omicron è arrivata anche in Vallec...
# 99      La variante Omicron al momento in Italia rappr...
# 100     Il totale di casi della nuova variante in Prov...
# 101     Si aggiorna la mappa dei colori delle regioni ...
# 102     Inglese, brasiliana, sudafricana ma anche indi...
# 103     Scoperta una nuova variante del coronavirus in...
# 104     Coronavirus, individuata la 'variante di Bagna...
# 105     "Circola dai primi di agosto in Italia una var...
# 106     Coronavirus: la variante inglese è arrivata a ...
# 107     LECCE - Sta destando preoccupazione in Salento...
# 108     Ha quarant’anni e sta vivendo a casa il suo is...
# 109     Potrebbe trattarsi del primo caso in Umbria di...
# 110     LIVORNO. Un caso di scabbia alla scuola primar...
# 111     EBOLI - Un sospetto caso di meningite scatena ...
# 112     ....da lunedì 14 febbraio, in zona arancione c...
# 113     Variante Omicron, in Italia il 31 gennaio era ...
# 114     La presenza della variante Omicron 2 in Italia...
# 115     Sequenziata oggi,  per la prima volta in Emili...
# 116     Variante Delta plus, dai dati aggiornati al 21...
# 117     Da fine agosto in Emilia-Romagna sono stati ri...
# 118     ...Delta Plus è in Friuli Venezia Giulia da al...
# 119     Si aggiorna nuovamente la mappa dei colori del...
# 120     Oltre alle 3 varianti di coronavirus che desta...
# 121     ASCOLI - Una nuova variante del virus è stata ...
# 122     Coronavirus: individuato il primo caso di vari...
# 123     Roma, 19 aprile 2022 (Agonb) – Si chiama BA.2....
# 124     ...Secondo quanto comunicato dall’Istituto Zoo...
# 125     Ora è ufficiale. Il nuovo sequenziamento, effe...
# 126     [...]  La variante Omicron 2 è al 97% di preva...
# 127     l presidente facente funzioni della Regione Ca...
# 128     Il presidente facente funzioni della Regione m...
# 129     La variante Delta di Sars-CoV-2 continua ad es...
# 130     È risultato positivo al Covidi-19 un intero nu...
# 131     Ultraottantenni e con patologie pregresse, osp...
# 132     Intervento dell'Asl per eseguire i controlli e...
# 133     Nella Asl Roma 2 «è in corso l'indagine epidem...
# 134     Il focolaio di Torano non si spegne. I tamponi...
# 135     La struttura sanitaria privata su via Ardeatin...
# 136     La circolazione delle varianti del Covid-19 in...
# 137     È allarme variante inglese. Il rischio associa...
# 138     Un virus nel virus. Anzi, una «sub-epidemia» n...
# 139     L’Emilia-Romagna ha concluso il primo studio s...
# 140     VENEZIA. Si evidenzia: il ''consolidarsi della...
# 141     Torna sotto la soglia dei 200 il numero dei pa...
# 142     GORIZIA - "Le misure restrittive riguardanti i...
# 143     MESTRE - Sette alunni e un’insegnante di una c...
# 144     PESCARA - Sale al 65 per cento in Abruzzo la p...
# 145     C'è preoccupazione per la variante inglese. An...
# 146     E’ stata avviata un’indagine mirata per l’anal...
# 147     Quattro i casi positivi alla variante inglese ...
# 148     Alcuni casi di variante inglese del Coronaviru...
# 149     Dopo il focolaio accertato a Bollate, alle por...
# 150     Covid, in Lombardia anche la "variante scozzes...
# 151     Genova. l team dell’Unità Operativa di Igiene ...
# 152     VENEZIA, FEB 17 - C'è anche la variante brasil...
# 153     Nome in codice "B1.525". Si chiama così la nuo...
# 154     Si torna a parlare di zona rossa in Italia. No...
# 155     Stando ai dati raccolti finora nel mese di giu...
# 156     I contagiati fanno tutti parte del focolaio di...
# 157     Èdi un signore di 80 anni ricoverato presso la...
# 158     In Piemonte, dai dati diffusi oggi da Arpa (Ag...
# 159     Sono nove le varianti del Covid (contrassegnat...
# 160     Mentre l'Europa, l'Africa e l'Asia sono alle p...
# 161     C’è una nuova variante Covid, scoperta dall’Un...
# 162     Che cosa potrebbe cambiare dal 27 settembre? A...
# 163     Ora lo studio è concentrato sulle varianti Cov...
# 164     Sono due i casi accertati di variante Mu isola...
# 165     .... I colori delle Regioni da lunedì 21 febbr...
# 166     La sottovariante di Omicron, BA.2, chiamata in...
# 167     Milano, 18 feb. (Adnkronos Salute) - "I campio...
# 168     MESTRE Potrebbe essere il terzo falso allarme,...
# 169     In sintesi... /div> div id=tt-text> p>Fai un c...
# 170     La paziente aveva solo una normale influenza ,...
# 171     Dopo i casi di meningite registrati nei mesi s...
# 172     SOLBIATE OLONA – Un caso di scabbia all’asilo ...
# 173     È successo in una Materna: la piccola ha la fe...
# 174     Sono in “lievissimo” miglioramento le condizio...
# 175     Dopo Folgarida, tocca al Monte Bondne: anche q...
# 176     E' stata isolata e genotipizzata presso il lab...
# 177     08 mag 2021. L’Italia è quasi tutta in giallo,...
# 178     La temuta variante indiana del Covid circola o...
# 179     Coronavirus: primi casi di variante indiana in...
# 180     La variante indiana del Covid raggiunge anche ...
# 181     Coronavirus, primi due casi di variante indian...
# 182     TAURISANO (Lecce) I sospetti sono diventati co...
# 183     Soltanto uno su 23 presenta le caratteristiche...
# 184     REGGIO EMILIA – “Nel reggiano e in generale in...
# 185     Perugia, 5 maggio 2021 - "Fino adesso i casi d...
# 186     Tutte le mini zone rosse in Italia decise per ...
# 205     Una nuova variante del Covid-19, Xe, è sotto m...
# 206     In Sicilia abolite le zone rosse dopo il nuovo...
# 207     CATANZARO – Con l’ordinanza numero 61 firmata ...
# 208     La prossima Variante Delta si chiama "Mu". Ma,...
# 209     Sono risultati negativi al #coronavirus tutti ...
# 210     L’ultimo decesso riguarda un 88enne di Caselle...
# 211     #Coronavirus: dallo Spallanzani i primi due ca...
# 212     +++ #Coronavirus: Il test effettuato presso l’...
# 213     È risultato positivo al coronavirus un diciass...
# 214     Sono tutti negativi al test del “coronavirus c...
# 215     Salgono a quattro i casi di coronavirus in Pie...
# 216     Nuovo caso di positività al Coronavirus in Emi...
# 217     A Vigodarzere una persona è risultata positiva...
# 218     Enna. Riunione in Prefettura oggi per fare il ...
# 219     Un caso di tubercolosi, estesosi dal paziente ...
# 220     in foto: Foto di repertorio. Un bambino di ott...
# 221     L’Italia cambia di nuovo colore: da oggi, lune...
# 222     In tutta Italia aumentano le segnalazioni di c...
# 223     Dopo quella inglese e brasiliana, primo caso d...
# 224     È stata confermata per la prima volta in Sarde...
# 225     Una nuova e particolarissima mutazione del cor...
# 226     La firma del ministro della Salute, Speranza. ...
# 227     Ecdc: al 13 dicembre risultano 1.686 casi in E...
# 228     L'istituto zooprofilattico della Lombardia e d...
# 229     Primo caso di variante Omicron oggi in Sicilia...
# 230     A  Lodi è arrivato il primo caso della variant...
# 231     Siena, 13 dicembre 2021 - È stato individuato ...
# 232     Nel Laboratorio di Igiene del Policlinico san ...
# 233     Tre casi di variante Omicron del Coronavirus s...
# 234     Primo caso di variante Omicron in Piemonte. È ...
# 235     La variante Omicron arriva in Puglia. I primi ...
# 236     ...Si tratta di un soggetto, di circa 30 anni,...
# 237     È stato individuato anche nel Nord Sardegna il...
# 238     Èstata sequenziata per la prima volta in Venet...
# 239     ...Ancora una volta, anche i campioni prelevat...
# 240     E’ un uomo di Luzzara il primo italiano contag...
# 241     Un giovane del bellunese, rientrato dalla Cina...
# 242     IL RICOVERO Tra questi sessanta c'è un ventenn...
# 243     L'infezione appare comunque clinicamente seria...
# 244     ... infettive del Cardarelli di Campobasso. Er...
# 245     Livorno – La donna di 30 anni della Valdera co...
# 246     Ci si avvicina al picco epidemico stagionale d...
# 247     Dopo l’accoppiamento gli acari adulti maschi r...
# 248     in foto: foto di repertorio. Un uomo di 56 ann...
# 249     Un altro caso di meningite sul lago d'Iseo, ne...
# 250     ....... Il ministro Speranza ha firmato l'ordi...
# 251     Gli esiti riferiti ai campioni dell'ultima set...
# 252     CAGLIARI. La variante Omicron 2 sbarca in Sard...
# 253     Scattano restrizioni da lockdown in alcuni pae...
# 254     In nottata è stato registrato al Cotugno un nu...
# 255     ROMA. Negativo il test del coronavirus sul paz...
# 256     «La tubercolosi si cura e già venerdì (domani ...
# 257     Nel Basso Sebino una donna di 71 anni colpita ...
# 258     TREVISO. L’influenza torna a fare paura nella ...
# 259     Registrato un picco di accessi al pronto socco...
# 260     Firenze, 1 febbraio 2020 - Tracce di legionell...
# 261     In un'altra azienda bresciana è stato riscontr...
# 262     Veneto, scoperti due focolai di influenza avia...
# 263     L'assessore alla Salute della Regione Umbria, ...
# 264     Anche a Cosenza è stato individuato un caso di...
# 265     REGGIO CALABRIA «I media nazionali hanno ripor...
# 266     Fioriscono le nuove varianti del virus: al San...
# 267     Verso le dimissioni dal Cotugno di Napoli il 4...
# 268     Allarme scabbia in un asilo nido e in una scuo...
# 269     È morto a quattordici anni Rosario, alunno del...
# 270     "Un detenuto su tre è straniero, diversi hanno...
# 271     Si chiama "Xf", è una nuova variante del coron...
# 272     Èstata isolata per la prima volta in Italia, d...
# 273     È stata isolata in Piemonte la nuova variante ...
# 274     È stata identificata nel Veneto una nuova vari...
# 275     Attualmente gli 80% dei casi di Covid-19 in It...
# 276     Aggiornamento 7 ottobre 2021: Cambiano in anti...
# 277     8 ottobre 2021. Venti cittadini positivi al vi...
# 278     Roma, 8 ottobre 2021 "Nel 100% dei casi è stat...
# 279     È stato sequenziato in Sardegna, nei laborator...
# 280     BA.2.75, la variante di Sars Cov 2 ribattezzat...
# 281     Da oggi, lunedì 7 febbraio, le Marche passano ...
# 282     L’aumento dei contagi causato dalla variante D...
# 283     Firenze, 6 ganaio 2021 - Scoperto un caso di v...
# 284     Appello dell’Organizzazione Mondiale della San...
# 285     La variante del Covid-19 individuata per la pr...
# 286     Nasce il consorzio per il sequenziamento del S...
# 287     «Stiamo eseguendo studi sulle nuove varianti d...
# 288     Covid, accertati 6 casi di variante inglese ne...
# 289     PRATO. Sono 40 i nuovi contagi di coronavirus ...
# 290     Trovata in Fvg la variante inglese del covid „...
# 291     SAPRI - Storditi, confusi, preoccupati: si son...
# 292     Genova. Sono 3 i casi di variante inglese del ...
# 293     Pur risultato positivo alla variante inglese d...
# 294     L'Istituto Zooprofilattico Sperimentale dell'A...
# 295     (ANSA) - NAPOLI, 27 GEN - I tre casi di varian...
# 296     Sono una decina i cluster familiari in cui è s...
# 297     In Portogallo la variante BA.5 è già dominante...
# 298     In Italia il 7 giugno scorso la variante Omicr...
# 299     Le varianti del Coronavirus Omicron BA4 e BA 5...
# 300     Omicron BA.5 è diventata la seconda variante d...
# 301     Sia nel primo caso, segnalato nel Varesotto, a...
# 302     Zaia: "Abbiamo scientificamente dimostrato che...
# 303     Il caso italiano asintomatico, sta bene ma ha ...
# 304     Una coppia e il figlio sono in isolamento a Lo...
# 305     Mentre nel Regno Unito cresce l'allarme per la...
# 306     Covid, anche in Veneto è ormai la variante Omi...
# 307     Dai dati diffusi da Arpa, gli esiti delle anal...
# 308     Nel nord Sardegna la Omicron BA5 è la variante...
# 309     In Italia il 2 agosto scorso la variante Omicr...
# 310     Omicron 5 è la variante dominante in Calabria....
# 311     .... la prevalenza della variante Omicron 5 ha...
# 312     In Liguria si registra un aumento dei casi del...
# 313     La nuova variante del Covid che sta allarmando...
# 314     Nuovi cambi di colore in vista per alcuni terr...
# 315     Da domenica prossima, 16 gennaio, saranno 149 ...
# 316     La variante Omicron del coronavirus SARS-CoV-2...
# 317     Deltracron è arrivata in Italia ma il mix di v...
# 323     Covid: crescita positivi legata anche a focola...
# 324     Un paziente è stato prelevato da casa con l'am...
# 325     26 FEB – Due persone sono ricoverate all’osped...
# 326     E' stato effettuato questa mattina un tampone ...
# 327     BOLOGNA – Il primo contagio registrato nel rim...
# 328     Tamponi negativi per la moglie e il figlio. «I...
# 329     CARPI (Modena) – Salgono a cinque i casi di po...
# 330     Nuovo Coronavirus – Negativi esami altri sospe...
# 331     In questo articolo troverete tutti gli aggiorn...
# 332     Al momento sono una regione si trova in zona r...
# 333     Sono Nardodipace (Vibo Valentia) e la frazione...
# 334     La variante Delta (ex Indiana) rappresenta orm...
# 335     La comunità medico-scientifica sta monitorando...
# 336     La variante Omicron di Sars-CoV-2 resta protag...
# 337     Dopo il boom di contagi in Portogallo, la sott...
# 338     In Abruzzo è arrivata ufficialmente la variant...
# 339     Primo caso in Campania di Variante Portoghese ...
# 340     Il laboratorio centrale del Policlinico Duilio...
# 341     Continuano a crescere le misure adottate a liv...
# 342     Roma, 25 febbraio 2021 - La curva epidemica de...
# 343     Coronavirus in Friuli Venezia Giulia, aumenta ...
# 344     Per approfondire:  covid  varianti  test  aume...
# 345     In Emilia-Romagna "le varianti hanno attecchit...
# 346     SABAUDIA/PONZA – Un allarme variante inglese, ...
# 347     Covid-19, boom di varianti all’esame dei tampo...
# 348     BARI - Il Policlinico di Bari e l’Istituto Zoo...
# 349     SASSARI. In Sardegna arriva un nuovo caso di v...
# 350     SAN TEODORO. San Teodoro diventa zona Rossa. A...
# 351     Primi due casi di variante brasiliana del Coro...
# 352     In Abruzzo si registra un caso di sospetta var...
# 353     PALERMO. Il Sicilia c'è il primo caso di varia...
# 354     È cominciato all'Istituto zooprofilattico il m...
# 355     Boom di Focolai Covid Sanitari. Solo nelle ult...
# 356     ROMA – Due bimbi che erano in quarantena alla ...
# 357     VIGEVANO. Giornata d’alta tensione al San Matt...
# 358     OLBIA. Una coppia, marito e moglie di Olbia so...
# 359     Sono entrambi positivi al figli della coppia d...
# 360     Un caso sospetto di Coronavirus anche in provi...
# 361     Avezzano. “Non c'è alcun contagio da Coronavir...
# 362     Cronaca di Napoli: una maestra della scuola Pi...
# 363     Tubercolosi : test negativi anche sui rimanent...
# 366     Zona gialla e zona arancione, da domani - lune...
# 367     È arrivata anche in Italia la nuova variante O...
# 368     Rispetto a molte altre regioni italiane in Val...
# 369     Al 10 gennaio la variante Omicron del covid er...
# 370     Dal 35 all'80 per cento. Aumentano i casi di v...
# 371     "La variante Omicron si è già allargata a macc...
# 372     Il polverone sollevato dal magazine finanziari...
# 373     Il giovane presenterebbe i sintomi di una fort...
# 374     19/02/2020 - E’ deceduta oggi nel reparto di R...
# 375     FABBRICO . La Direzione Sanitaria dell’Ausl ha...
# 376     Sanremo . Ci sarebbero altri casi di bambini r...
# 377     Aggiornamento del 31 maggio 2021  Sulla base d...
# 378     Con l'arrivo dell'estate, il 21 giugno, l'Ital...
# 379     ANCONA - Nessuna allerta segnalata, classifica...
# 380     Nonostante la campagna di vaccinazione, a Cani...
# 381     In Italia la variante inglese del coronavirus ...
# 382     E’ nigeriana la variante del Covid trovata sui...
# 383     Da domani lunedì 28 marzo 2022 tutte le region...
# 384     Nelle Marche la variante Covid Omicron 2 è ora...
# 385     La variante BA.2, nota come Omicron 2 di Sars-...
# 386     Il Covid torna a mandare in apprensione il cal...
# 387     Allarme coronavirus in Sardegna. Un bambino di...
# 388     , ricoverata in via precauzionale al Policlini...
# 389     Nessun caso di coronavirus. E' stato scongiura...
# 390     VIGEVANO. Stroncato in poche ore da un’infezio...
# 391     Un lavoro di equipe preciso e veloce per accer...
# 393     Coronavirus: la variante inglese è arrivata a ...
# 397     Da domani cambiano di nuovo i colori della map...
# 398     In tutta Italia aumentano le segnalazioni di c...
# 399     Aosta - Da quanto si apprende la scoperta è av...
# 400     Sequenziata in Italia per la prima volta la va...
# 401     Coronavirus, scoperte 4 nuove varianti: ventin...
# 402     Le varianti del coronavirus sinora individuate...
# 403     Coronavirus, variante nigeriana al Policlinico...
# 404     La mascherina continua a essere uno degli stru...
# 405     Da lunedi anche l’Alto Adige passa in zona gia...
# 406     L’ordinanza che aveva dichiarato la zona rossa...
# 407     Bolzano - La variante Omicron arriva a Bolzano...
# 408     "La variante Omicron del Covid-19 è stata sequ...
# 409     Dopo il caso della Campania, l’allarme variant...
# 410     ROMA – Un paziente non vaccinato ricoverato pr...
# 411     Omicron 5 è diventata la sottovariante di Sars...
# 412     Nel mondo, il numero di casi settimanali di Co...
# 413     “Le varianti Omicron 4 (BA.4) e soprattutto Om...
# 414     #25febbraio #Coronavirus Ecco la tabella uffic...
# 415     In seguito a delle verifiche condotte sui tamp...
# 416     Nessun caso di coronavirus, dunque, ma una sem...
# 417     Sono saliti a 38 i casi di persone positive al...
# 418     Sono tutte negative le persone che sono state ...
# 419     Coronavirus, Cirio#x3a; "Il PIemonte non è un ...
# 420     Sono saliti a dieci i pazienti risultati posit...
# 421     Sono fortunatamente negative le analisi per il...
# 422     Negativo . Questo l'esito al test del Coronavi...
# 423     L'AQUILA - Sono risultati tutti negativi al Co...
# 424     Nel capoluogo siciliano, positiva una donna di...
# 425     Coronavirus, il punto della situazione in prov...
# 426     ANCONA – Coronavirus: sono negativi tutti i se...
# 427     Provvedimento in vigore da stasera, valido fin...
# 428     È in corso di valutazione presso l'Ospedale di...
# 429     Coronavirus, confermato il secondo caso di var...
# 430     ... L'Istituto superiore zooprofilattico delle...
# 431     Continua a diffondersi senza tregua la variant...
# 432     La storia di Guardiagrele, paese di 9.000 anim...
# 433     Roma, 16 gennaio 2021 - Aumentano le varianti ...
# 434     Coronavirus covid | Scoperto il primo caso di ...
# 435     Covid, trovato un caso positivo alla cosiddett...
# 436     Coronavirus: a Firenze caso sospetto di "varia...
# 437     Pisa, 14 gennaio 2021 - Il virologo Mauro Pist...
# 438     (ANSA) - ROMA, 13 GEN - La cosiddetta variante...
# 439     (Agenzia Vista) Ginevra, 11 gennaio 2021 Coron...
# 440      AGO 15, 2021  Questi dunque i colori delle re...
# 441     09 ago 2021. Due zone rosse in Calabria e inte...
# 442     In decisa crescita in tutto il mondo, la Delta...
# 443     Dopo il ricovero di un'insegnante per meningit...
# 444     ... al Policlinico di Bari dopo essersi presen...
# 445     PONTEDERA. Allarme tubercolosi all’ospedale Lo...
# 446     CORREGGIO (Reggio Emilia) – La Direzione Sanit...
# 447     Ci si avvicina al picco epidemico stagionale d...
# 448     PAVIA. Da due settimane sta lottando contro la...
# 449     Si sa, è inverno, un inverno caldo, e i virus ...
# 450     . Impiegato presso i supermercati Visotto, è s...
# 451     In Italia la variante covid alfa, che si era i...
# 452     Arriva dal Sud America la nuova variante Lambd...
# 453     Si prevede che la variante Delta .possa essere...
# 454     Il presidente della Regione Nello Musumeci pot...
# 455     La variante Alpha del Covid-19, così come è st...
# 456     "Continua il sequenziamento costante della Reg...
# 457     Un altro incredibile successo per la sanità ca...
# 458     La variante indiana torna a far paura in Pugli...
# 459     Coronavirus: grazie all’attività di tracciamen...
# 460     Non ce l'ha fatta Valentina, la bambina valdos...
# 461     Sanremo. Caso di scabbia in un asilo del Borgo...
# 462     Potrebbe essere stato il "famigerato" Noroviru...
# 463     ...  Le mini zone rosse e arancioni comunali e...
# 464     ....Nuove varianti del coronavirus possono svi...
# 465     Da Israele è arrivata una notizia piuttosto so...
# 466     nche la prima nuova variante di SARS-CoV-2, ch...
# 467     La sottovariante Omicron BA.2.75 del corovavir...
# 468     Pochi minuti per contagiarsi con Centaurus , t...
# 469     Omicron 5 è ormai dominante in tutto il mondo....
# 470     Simona Granati - Corbis via Getty Images ROME,...
# 471     . Condizioni stazionarie per la studentessa ri...
# 472     sono passati al Sant’Orsola? "Finora ne abbiam...
# 473     VERONA Due ricoveri nel giro di 24 ore, a Vero...
# 474     29 Agosto 2021. Nuova “zona rossa” in provinci...
# 475     ....E' tornata in circolazione in Romagna la v...
# 476     Nella mappa dell’Italia colorata in base alle ...
# 477     Aritzo in lockdown, focolaio Covid dopo decine...
# 478     Una nuova “zona rossa” in provincia di Agrigen...
# 479     È stata identificata una nuova variante di cor...
# 480     Covid, i numeri scendono ma l'allerta resta al...
# 481     La variante inglese di Sars-CoV-2 (B.1.1.7) da...
# 482     Nell’ultima settimana il laboratorio diretto d...
# 483     Come ondate dell’oceano arrivano ciclicamente,...
# 485     Da oggi, lunedì 17 maggio, quasi tutta Italia ...
# 486     E' una delle osservate speciali. La variante i...
# 487     Sono al momento 52 i casi di variante indiana ...
# 488     È stato rilevato un caso di variante indiana a...
# 489     ... Vaia: "Scoperte varianti meno pericolose s...
# 490     Anche il Centro Abruzzo toccato dalla variante...
# 491     In Friuli Venezia Giulia è stata rilevata la p...
# 492     ... Con l'ordinanza appena firmata dal ministr...
# 493     Sono tre le “sorelle” della variante Omicron (...
# 494     "In questa settimana c'è stata un'inversione n...
# 495     Nell’ultima settimana la curva del contagio da...
# 496     “In Campania la sottovariante Omicron 5 è al 9...
# 497     10 GENNAIO 2022. Da oggi l'Italia è per tre qu...
# 498     Il presidente della Regione Calabria, Roberto ...
# 499     Sono 32 le province nelle quali la pandemia di...
# 500     La variante Omicron ha sorpassato nelle Marche...
# 501        La variante Omicron è stata trovata anche n...
# 502     La variante Omicron circolava a Milano già al ...
# 503     Il 'passaggio di consegne tra Delta e la Omicr...
# 504     Sono 804 i detenuti positivi - dei quali 22 nu...
# 505     ... Il contagio avanza senza freni, in tutta l...
# 506     La presenza di nuovi focolai covid-19 accertat...
# 507     L’emergenza Coronavirus è ancora presente sul ...
# 508     La mutazione E484K nella proteina spike del vi...
# 509     In Alto Adige tornano le zone rosse Covid: con...
# 510     (ANSA) - CAGLIARI, 19 NOV - C'è un caso di var...
# 511     E' arrivata anche in Sicilia la nuova variante...
# 512     TRENTO. "Serve molta disciplina e rispetto del...
# 513     Nel momento in cui a Corzano, nella bassa bres...
# 514     Tra i paesi bresciani che in questi giorni tra...
# 515     Un cluster sta interessando alcune famiglie a ...
# 516     SPIGNO SATURNIA – “Registriamo oggi sul territ...
# 517     Mini Cluster Covid a Contrada. Sette le person...
# 518     Emergenza Covid, 20 positivi in un giorno: con...
# 519     Intanto preoccupa l'impennata di contagi ad Av...
# 520     A Ravello sono stati accertati sei nuovi casi ...
# 521     Vallata.  Contagi da Covid, infezioni a raffic...
# 522     Esplode la bomba covid a Forio. Un cluster fam...
# 523     Imperia. Il plesso scolastico che ospita l’Ist...
# 524     Livorno, nuovi casi di contagio tra docenti e ...
# 525     L’ordinanza  Con l’ordinanza firmata il 7 febb...
# 526     A Gussago 4 classi in isolamento per coronavir...
# 527     Nonostante tutte le precauzioni prese, alla fi...
# 528     Un focolaio di Covid è scoppiato all'istituto ...
# 529     Tre classi sono state poste in isolamento e un...
# 530     A Carpaneto, questa mattina, la scuola primari...
# 531     Sulla base delle linee guida della Regione Emi...
# 532     Ormai non passa giorno senza nuove quarantene ...
# 533     Sono due i focolai di contagi da Covid localiz...
# 534     Resta immutata per ora la situazione per le du...
# 535     PONTEDERA — Sono stati riscontrati alcuni casi...
# 536     Pontremoli (Massa Carrara), 4 febbraio 2021 - ...
# 537     Pisa, 7 febbraio 2021. Sette studenti della sc...
# 538     Borgio Verezzi. Tre classi delle scuole medie ...
# 539     VALMUSONE – L’elevata contagiosità della varia...
# 540     PESARO - Cluster di positivi nei plessi della ...
# 541     Da oggi Petrella è in ‘semi’ lockdown: misure ...
# 542     Chiusura di tutte le scuole di ogni ordine e g...
# 543     Focolaio a scuola, sospese le lezioni in prese...
# 544     Covid, mini focolaio a scuola „Con un'apposita...
# 545     Somma Vesuviana (Na) – “Chiudo Infanzia ed Ele...
# 546     Bimbi positivi, in aula: chiuse scuole – come ...
# 547     Focolaio di Covid19 all’Istituto comprensivo s...
# 548     10 positivi tra alunni e docenti in una scuola...
# 549     Covid-19, contagi in una scuola: sospesa l'att...
# 550     Sono 21 i nuovi studenti positivi al Covid-19 ...
# 551     L’Istituto Marconi chiude per Covid. Dopo l’ac...
# 552     Tutte le scuole dell’infanzia, elementari e me...
# 553     Continua ad imperversare l’epidemia di Coronav...
# 554     L’evolversi dei contagi in città continua a in...
# 555     Scoperto un focolaio di contagi covid al pless...
# 556     Situazione sotto controllo" alla Rsa “Rita e L...
# 557     PAVIA. Nonostante la provincia di Pavia sia zo...
# 558     L'80% degli ospiti della casa per anziani del ...
# 559     Presso la clinica Rossello, la residenza prote...
# 560     Un nuovo cluster covid è stato isolato in una ...
# 561     C’è un nuovo focolaio di Covid alla casa di ri...
# 562     Coronavirus, si allarga il focolaio alla casa ...
# 563     Bologna, 5 febbraio 2021 - "Io non respiro, ma...
# 564     Marano (Modena), 8 febbraio 2021 - Il covid-19...
# 565     San Casciano (Firenze), 6 febbraio 2021 - Si a...
# 566     Un nuovo focolaio nella Capitale. L'Unità di C...
# 567     Le brutte notizie arrivano dal Benincasa, stru...
# 568     Nella struttura sanitaria registrati 2 positiv...
# 569     ALMUSONE – Resta complessa da gestire la situa...
# 570     (ANSA) - MONTERODUNI, 06 FEB - Cluster nella '...
# 571     Salgono a sette gli anziani deceduti per Covid...
# 572     Sono 110 gli anziani positivi al Covid e ospit...
# 573     CASSANO ALLO IONIO (COSENZA) – Il sindaco di C...
# 574     MARSALA – Il Covid-19 non risparmia nemmeno la...
# 575     Nuovo focolaio di Covid nella casa di riposo p...
# 576     È esploso un focolaio da Covid 19 all’ospedale...
# 577     Sul territorio bresciano dal punto di vista de...
# 578     A seguito dello screening effettuato su tutto ...
# 579     Dieci casi di coronavirus sono emersi al Polic...
# 580     Il primo caso risale a giovedì e da lì, via vi...
# 581     Covid-19: nuovo focolaio al Ruggi, 9 contagi i...
# 582     Tredici pazienti della Medicina d’Urgenza dell...
# 583     L’ospedale Maresca potrebbe diventare un nuovo...
# 584     Paziente trasferita risulta positiva, infettat...
# 585     CUMIANA (TORINO). A causa di un focolaio di co...
# 586     Sono in totale cinquanta i lavoratori della St...
# 587     MONSELICE - ....Intanto scoppia un focolaio Co...
# 588     Dopo il focolaio di Covid la Lega Pro ha decis...
# 589     CAMPIGLIA MARITTIMA — La sindaca Alberta Ticci...
# 590     Cluster al campo nomadi di Castel Romano, situ...
# 591     Coronavirus Roma, nuovo focolaio: 54 positivi ...
# 592     Focolaio di Covid-19 nel dipartimento Sanità d...
# 593     Nel carcere di Carinola, in provincia di Caser...
# 594     Covid, chiuso il Comando della Municipale „  D...
# 595     Covid, positivi operatori sociali „  Cinque op...
# 596     C’è un nuovo focolaio nella presila cosentina,...
# 597     Si era inizialmente parlato di 8 soggetti posi...
# 684     All'origine dei contagi ci sarebbe un dipenden...
# 685     Coronavirus: un neonato nel focolaio dell'Impr...
# 686     Padre, madre e due bimbi residenti nel comune ...
# 687     Nella Asl Roma 5 dei sei nuovi casi quattro so...
# 688     Individuato un focolaio Covid a Predazzo. Un c...
# 689     Regione Fvg monitora. Già eseguiti oltre 100 t...
# 690     Scoperto un nuovo focolaio di Coronavirus a Po...
# 691     Dopo che nei giorni scorsi Feltre era stata pr...
# 692     Focolaio di Coronavirus a Viareggio. Si tratta...
# 693     Sigilli alla struttura frequentata da due frat...
# 694     Nei giorni scorsi a Trescore è stato individua...
# 695     Un focolaio è scoppiato dopo le nozze di Giamp...
# 696     Numeri in aumento per i residenti a Monte Comp...
# 697     Focolai familiari e un cluster dopo una festa ...
# 698     ...“La situazione di oggi è completamente dive...
# 699     Pepe: “Non abbassiamo la guardia. Conosco la m...
# 700     Riguardo al focolaio originatosi all’interno d...
# 701     ...A Gavardo per esempio in due giorni, gioved...
# 702     Milano, 11 febbraio 2021 - La scuola d'infanzi...
# 703     Esplodono i contagi da coronavirus ad Arcene e...
# 704     Dieci positivi e altri casi sospetti: quarante...
# 705     "Dalle scuole arrivano notizie non incoraggian...
# 706     Le scuole possibili focolai di contagi? Le org...
# 707     „Dopo la quarantena scattata per una sezione d...
# 708     Il Covid ha costretto alla chiusura forzata al...
# 709     Sono una settantina i focolai da Coronavirus a...
# 710     Nelle regioni del Centro Italia aumenta l'alla...
# 711     CASTELFIDARDO -  L’Asur pone fine al braccio d...
# 712     In seguito a uno screening di massa su tutte l...
# 713     MARIGLIANO - Focolaio Covid-19 all' istituto c...
# 714     Sono 26 gli studenti nuovi contagiati dal viru...
# 715     Chiuse per Covid a Salerno due scuole: si trat...
# 716     TORRE DEL GRECO. La morte della maestra elemen...
# 717     Presunti casi Covid-19 nelle scuole di Avella,...
# 718     In Campania 29 focolai nelle scuole negli ulti...
# 719     POLICORO - Il sindaco di Policoro, Enrico Masc...
# 720     POTENZA – Altri due focolai scolastici di covi...
# 721     Dopo varie insistenze da parte dei genitori l’...
# 722     Sono 19 i casi di positività al Covid registra...
# 723      Chiusa la scuola Ugo Foscolo di via Salvator ...
# 724     Altri dodici contagi alla Caris di via Montell...
# 725     Era stato chiarito fin da subito: il vaccino P...
# 726     PADOVA. Non è ancora finita. Margrado il croll...
# 727     ACQUI TERME - Da ormai qualche giorno sulla ma...
# 728     Gli anziani ospiti di una casa protetta privat...
# 729     Cluster nella casa di riposo di Roccagorga: l’...
# 730     Il centro per anziani "La Finestra sul Mare" d...
# 731     ANCONA – Si allarga il cerchio dei focolai cov...
# 732     A darne notizia è Raffaele de Leonardis, sinda...
# 733     Sono 43 le persone risultate positive nella Re...
# 734     POTENZA – Un nuovo focolaio (dopo quello venut...
# 735     “Lascia spazio ad una serie di perplessità la ...
# 736     Due nuovi cluster in reparti bianchi dell’ospe...
# 737     LORETO - Il Covid non risparmia l’Hospice di L...
# 738     Apprensione e preoccupazione per un focolaio C...
# 739     Catania - La Variante inglese sarebbe arrivata...
# 740     Il Covid-19 torna a fare, concretamente, paura...
# 741     SESTO SAN GIOVANNI - Ora è ufficiale: Pro Sest...
# 742     Sedici persone positive al covid-19, di cui al...
# 743     La Givova Scafati rende noto che il settore ag...
# 744     Un focolaio di Covid 19 tra i giocatori di bea...
# 745     Focolaio covid a Castel Romano: rom in quarant...
# 746     Carsoli. Dieci persone sono risultate positive...
# 747     „Situazione preoccupante nel carcere teatino d...
# 748     Originario di Maddaloni, rappresentante sindac...
# 749     Pepe: "Non abbassiamo la guardia. Conosco la m...
# 750     MATERA - Il numero accertato dei casi di posit...
# 751     Una di loro, non sapendo di aver contratto il ...
# 752     MASSAROSA — Resterà chiusa per una settimana, ...
# 753     Terni, focolaio Covid alla scuola elementare: ...
# 754     A Noicattaro, stando a quanto comunica il sind...
# 755     SAN SEBASTIANO CURONE - "E' scoppiato un clust...
# 756     l Covid fa breccia nelle Rsa: da Carpenedolo a...
# 757     TRENTO. C'è un nuovo focolaio in Trentino e an...
# 758     FELTRE. È rimasta sempre Covid free, la casa d...
# 759     Focolaio Covid in una Rsa: 70 contagiati tra a...
# 760     Ha destato comprensibile preoccupazione il foc...
# 761     Sono 189 in tutto, nel Tigullio, gli anziani o...
# 762     Dopo le due positività all’interno della casa ...
# 763     Focolaio di Coronavirus nella casa protetta: p...
# 764     I tamponi effettuati lunedì nell’ambito del pi...
# 765     Il sindaco Elena Carletti ha commentato la sit...
# 766     FOLLONICA – Crescono i casi di Coronavirus nel...
# 767     Focolaio nella Rsa di Pratovecchio-Stia (Arezz...
# 768     Chianciano Terme (Siena), 27 novembre 2020 - F...
# 769     Focolaio nella casa alloggio per anziani. Quas...
# 770     Viterbo – Focolaio alla casa di riposo residen...
# 771     Focolaio di Covid in provincia di Roma nella c...
# 772     Cluster nel complesso per anziani gestito dall...
# 773     Secondo l’ultimo bollettino Asl, dei 90 nuovi ...
# 774     Nella seconda ondata della pandemia da coronav...
# 775     Coronavirus Aprilia, nuovo cluster in una Rsa:...
# 776     Fra i 106 positivi al Covid registrati a Filot...
# 777     L'ospedale frentano "ignorato" anche nella fas...
# 778     Covid-19: focolaio in una casa di riposo di Br...
# 779     Tora e Piccilli – Un piccolo focolaio Covid19 ...
# 780     Sono 39 le persone che hanno contratto, in var...
# 781     Cluster nella casa di riposo per anziani "Mons...
# 782     Piano di Sorrento: focolaio covid nella casa d...
# 783     Teggiano (SA). Il Covid si insinua nelle case ...
# 784     Un focolaio di coronavirus è stato accertato n...
# 785     ACCADIA - Sono risultati positivi al Covid 39 ...
# 786     Un focolaio di coronavirus è stato accertato n...
# 787     48 ospiti della casa di riposo “Raffaele Acere...
# 788     Sarebbero 19 gli anziani ospiti della struttur...
# 789     Coronavirus, focolaio alla Casa di Riposo Cann...
# 790     Coronavirus, focolai in due case di riposo: in...
# 791     Casa di riposo focolaio: in azione i medici Us...
# 792     Il Covid-19 entra per la prima volta in una ca...
# 793     Focolaio alla Casa Piccolo Cottolengo, ritardo...
# 794     Ca' Foncello, cinque anziani contagiati nel re...
# 795     Pavia, 28 novembre 2020 - Un focolaio Covid è ...
# 796     Paura per un focolaio di Covid all’ospedale di...
# 797     Pesaro, 30 novembre 2020 - Si allarga il conta...
# 798     Un nuovo focolaio nella Capitale. L'Unità di C...
# 799     ULMONA – Un gruppo di infermieri e operatori s...
# 800     Cava de’ Tirreni. Sono saliti a 33 i casi di c...
# 801     Le persone risultate positive al Covid-19 nel ...
# 802     Sedici gli ospiti disabili contagiati mentre o...
# 803     MORMANNO. Tredici casi di Covid–19 accertati p...
# 804     Sono 3 i casi positivi al coronavirus riscontr...
# 805     Un nuovo focolaio di Covid-19 all’Ospedale Civ...
# 806     Visto che le strutture sanitarie non provvedon...
# 807     AsuGi informa che due guardie carcerarie della...
# 808     Il Responsabile dell’Area Tecnica dell'Udinese...
# 809     Focolaio dopo la battuta di caccia, Piccinini:...
# 810     La notizia è emersa soltanto ieri da alcuni ar...
# 811     Situazione covid-19 nei comuni dei Picentini, ...
# 812     Si aggrava il triste bilancio dei decessi per ...
# 813     Il virus entra in banca a Scafati. Tre positiv...
# 814     Altri due decessi al Rummo e lo spettro di un ...
# 815     Il «caso» di Talsano  Sta diventando un epidem...
# 816     TRAPANI – Il Covid 19 a bordo. È successo sull...
# 817     Un piccolo focolaio si è scoperto in due centr...
# 818     Si è sviluppato un focolaio di Coronavirus al ...
# 819     Il coronavirus entra anche nella comunità di r...
# 820     Dalla Lombardia alla Campania, preoccupa - non...
# 821     La variante Delta in Lombardia rappresenta qua...
# 822     ...Si attesta intorno al 30% l'incidenza della...
# 823     Bari - La variante Delta avanza in Puglia. Sec...
# 824     Un caso di contagio su due è dovuto alla varia...
# 825     “In Campania la variante Delta del Covid è arr...
# 826     VERONA - Come festeggiare la maturità nel pegg...
# 827     Ci sono due feste private tra giovani, a Jesol...
# 828     Ancora una virata all’insù per la curva epidem...
# 829     Stando alle informazioni diffuse dalla Asl Rom...
# 830     Un cluster di Coronavirus si è verificato ad u...
# 831     CARTOSIO – Focolaio covid a Cartosio. Da ieri ...
# 832     Le prime persone che in Valle d'Aosta sono ris...
# 833     VALLE D'AOSTA - 4 maestri di sci spagnoli che ...
# 834     Sesto San Giovanni (Milano), 13 luglio 2021 - ...
# 835     Un nuovo cluster e tanta preoccupazione per un...
# 836     A seguito di un caso di positività al Covid-19...
# 837     Lo Spezia ha comunicato che sei calciatori e u...
# 838     In provincia di Ferrara si devono contare altr...
# 839     Nuovi casi fra i giovani turisti e super lavor...
# 840     FIRENZE — Tre persone positive al coronavirus ...
# 841     Come spiega la Repubblica, la variante ‘Europe...
# 842     Non solo pub e locali. Un cluster di 20 positi...
# 843     Un cluster si è avuto dopo una partita degli A...
# 844     Il Covid torna a viaggiare a Nocera Inferiore....
# 845     Focolaio Covid a Teverola, nel Casertano: 16 i...
# 846     Dopo la chiusura di un campo estivo con 44 pos...
# 847     Covid, focolai fra i ragazzi  dai 16 ai 19 ann...
# 848     Salgono a quattro i casi di coronavirus a Patt...
# 849     Palermo, 17 luglio 2021 - Allarme Covid a Pant...
# 850     Cresce ancora la preoccupazione per i casi di ...
# 851     I festeggiamenti per l’unione di una nuova cop...
# 852     L’Asl: il contagio in una notte in tenda nel g...
# 853     Il focolaio scoppiato dopo la festa degli Euro...
# 854     Alcune teorie del complotto parlano del corona...
# 855     Il nuovo coronavirus può diffondersi tramite p...
# 856     Sono diminuiti i contagi in Romagna stando al ...
# 857     Il reparto di chirurgia dell’ospedale di Desio...
# 858     Un cluster di Covid-19 è stato scoperto nei gi...
# 859     Focolaio di covid 19 all’interno della casa ci...
# 860     “Un intero nucleo famigliare residente a Roma,...
# 861     Il sindaco di San Fratello, Salvatore Sidoti P...
# 862     Il contagio sarebbe partito dagli specializzan...
# 863     “Dalla Asl di Rieti ci comunicano 8 nuovi posi...
# 864     Allerta alla Sibeg Catania, la fabbrica di imb...
# 865     L'istituto scolastico di via San Pelaio resta ...
# 866     Psicosi a L'Aquila dopo i nuovi positivi al Co...
# 867     In paese c’è chi parla di «situazione difficil...
# 868     Quasi metà degli ospiti positivi al covid nell...
# 869     Tra i 39 nuovi casi ben 6 bambini (2 con meno ...
# 870     Finora 13 positivi nella struttura, tra degent...
# 871     Si tratta della residenza per anziani Istituto...
# 872     A San Gemini chiuse le scuole di ogni ordine e...
# 873     E’ una situazione che diventa giorno dopo gior...
# 874     Otto casi positivi nel comune di Cori su 42 re...
# 875     È di cinque bambini contagiati al Coronavirus ...
# 876     Un nuovo focolaio di Coronavirus è stato indiv...
# 877     “Molfetta è al centro di una pandemia”. Così i...
# 878     Quindici dipendenti in servizio nelle sale ope...
# 879     Coronavirus, focolaio al Nomentana hospital: 2...
# 880     Il cluster all'interno della casa di cura "Cit...
# 881     Ancona, due positivi a Pietralacroce dopo una ...
# 882     L'Asl di Latina ha chiesto a tutti quelli che ...
# 883     Positivi al coronavirus quattro studenti del C...
# 884     Screening per tutti coloro che lavorano all'in...
# 885     In aumento i focolai Nella settimana dal 24 al...
# 886     Il coronavirus si riaffaccia a Capistrano, col...
# 887     Bondeno. È in corso un focolaio Covid-19 press...
# 888     ....Ma il primo cittadino di Bagno di Romagna ...
# 889     Sono 21 su 24 gli ospiti della casa di riposo ...
# 890     OSIMO - Il Covid torna a bussare alla casa di ...
# 891     VITERBO – Terzo cluster in pochi giorni nelle ...
# 892     Ancora un focolaio in una struttura per anzian...
# 893     Nelle ultime ore un focolaio covid ha interess...
# 894     Un decesso legato al Covid-19 nel Vallo di Dia...
# 895     Piove sul bagnato. Come se non bastassero le q...
# 896     Almeno altri 2 pazienti, ricoverati all'Aziend...
# 897     Focolaio covid nel delicatissimo reparto di On...
# 898     Scatta un nuovo grave  allarme all’ospedale Sa...
# 899     L’ufficio stampa di Amadeus ha reso noto che t...
# 900     GENOVA - Al carcere di Genova Pontedecimo ci s...
# 901     Nel comprensorio cilentano preoccupa la situaz...
# 902     Focolaio da Covid-19 in casa Napoli Basket. La...
# 903     EBOLI. Tre focolai Covid creano preoccupazione...
# 904     La Wow Green House Aversa ha comunicato alla L...
# 905     Nel comune di Sesta Godano, in provincia di La...
# 906     A Villalago, 600 abitanti nel cuore d'Abruzzo ...
# 907     VASTO. Boom di contagi a Vasto: 12 in un solo ...
# 908     Sono 3 i nuovi casi di positività al Covid-19 ...
# 909     Ventidue ospiti della casa di riposo Don Fagno...
# 910     l virus entra nelle stanze della Casa Santa Ma...
# 911     Nella residenza per anziani i positivi riscont...
# 912     La Direzione Sanitaria della Casa residenza an...
# 913     Coronavirus, focolaio alla "San Camillo": 34 p...
# 914     LUGO. Nuovo focolaio in una residenza per anzi...
# 915     Circa una trentina i casi con link alla casa d...
# 916     Sono oltre 60 gli ospiti risultati positivi al...
# 917     FABRIANO – Altro cluster da Coronavirus in una...
# 918     FABRIANO - Un focolaio Covid all’interno dell’...
# 919     La situazione dei contagi nel Comune di Scoppi...
# 920     Giulianova. A Giulianova si registra un focola...
# 921     VINCHIATURO, 29 OTT - Almeno 20 tra ospiti e o...
# 922     Cinque casi di positività al coronavirus sono ...
# 923     San Salvatore Telesino (Bn) – Covid-19 all’int...
# 924     Un focolaio di contagio anche nella struttura ...
# 925     Coronavirus a Roseto Valfortore: casi positivi...
# 926     Positivi al Coronavirus circa 30 persone tra p...
# 927     Coronavirus, 16 anziani positivi su 28: focola...
# 928     Castelsardo, 31 ottobre 2020 – Un focolaio Cov...
# 929     Un’altra scuola del Vicentino si trova a far l...
# 930     Due classi, quaranta tamponi, 17 alunni positi...
# 931     Il comune di Casorezzo, in provincia di Milano...
# 932     Tutta la classe a casa, almeno fino all’11 nov...
# 933     TOANO (Reggio Emilia) – In Appennino il primo ...
# 934     BRISIGHELLA. Nuovo focolaio tra i banchi di sc...
# 935     Firmata un’ordinanza con la quale il sindaco d...
# 936     La scuola Sinopoli a via Mascagni chiude per C...
# 937     Ci sono 12 alunni positivi nelle scuole di Lar...
# 938     Monitorata la situazione nel Cosentino dove, n...
# 939     Non conosce sosta l'avanzata del coronavirus n...
# 940     Scoperto un focolaio di coronavirus in una res...
# 941     Coronavirus, scoppia un focolaio nella casa di...
# 942     La scuola elementare Aldo Moro di Adelfia rest...
# 943     A partire da domani mattina su espressa richie...
# 944     Palermo, 2 nov. (askanews) – Il sindaco di Pie...
# 945     Coronavirus Lipari. Tra i contatti accertati d...
# 946     Scuole chiuse fino al 15 novembre a Bonorva. D...
# 947     Casi di coronavirus. E il sindaco di Cagliari ...
# 948     BUDDUSÒ. Buddusò e Luogosanto mandano in quara...
# 949     Sono giornate difficili all'ospedale di Cles. ...
# 950     VERONA   - All'ospedale Magalini di Villafranc...
# 951     Focolaio all’ospedale di Tradate in provincia ...
# 952     Covid-19, un focolaio tra gli operatori del pr...
# 953     Coronavirus: focolaio Covid all'ospedale di Tr...
# ...
# 3522    Dopo la comunicazione di altre tre positività,...
# 3523    SELLIA MARINA (CATANZARO) – Sono 56 i migranti...
# 3524    Emergenza Covid - Alla Rsa Garibaldi Pogliani ...
# 3525    Sono almeno sette i sanitari affetti dal virus...
# 3526    Diversi i reparti coinvolti, situazione partic...
# 3527    Si è sviluppato in quattro edifici di case pop...
# 3528    A San Salvatore sono stati contagiati 11 ospit...
# 3529    Un caso a Montevarchi nell'aretino e due nell'...
# 3530    Un nuovo focolaio di coronavirus sta preoccupa...
# 3531    Nella struttura contagiata un'infermiera. Nell...
# 3532    Usl 4: si allarga l’allarme nel Sandonatese do...
# 3533    Coronavirus, due nuovi focolai a Bologna „Sono...
# 3534    L'Italia fa i conti con l'istituzione di una n...
# 3535    Contagiati 13 operatori e 36 ospiti. Nessuno h...
# 3536    Si parla di una  recentissima diffusione del c...
# 3537    Quasi la metà dei cluster sono scoppiati tra i...
# 3538    Anche in provincia di Latina il Covid continua...
# 3539    Altri 1.682 casi per Rimini. Contagiati gli os...
# 3540    E’ scoppiato ad Avellino un brutto focolaio Co...
# 3541    Un focolaio di Covid-19 si è verificato nel re...
# 3542    Cluster al blocco operatorio dell’ospedale ‘Ma...
# 3543    E' un Lazio "allettato" dalla variante Omicron...
# 3544    Undici pazienti positivi al covid19. Torna a r...
# 3545    Focolaio al Gom di Reggio Calabria, nel repart...
# 3546    Anche in casa Juventus si fanno i conti col Co...
# 3547    Covid, cluster a Villa San Martino: 5 dipenden...
# 3548    BOLZANO.  Un focolaio di Covid è stato individ...
# 3549    Come previsto dal protocollo Fipav gli otto te...
# 3550    Altri tre nuovi tesserati positivi al Covid, s...
# 3551    Il cluster rilevato dal personale durante i co...
# 3552    Si tratta di un vero e proprio cluster in casa...
# 3553    Brindisi e cena il motivo della diffusione del...
# 3554    I contagi e le quarantene, già centinaia tra A...
# 3555    L’AQUILA – Focolaio nel consiglio regionale ab...
# 3556    ...La variante Omicron ha ormai il territorio ...
# 3557    Servizi essenziali a rischio per esplosione pa...
# 3558    Tre calciatori della prima squadra sono risult...
# 3559    Sarebbero almeno una decina i positivi al Coro...
# 3560    Desta preoccupazione il focolaio di Copertino,...
# 3561    CROTONE – Focolaio di Covid nel Crotone. Il cl...
# 3562    "Reggina 1914 comunica che, al termine del cic...
# 3563    MESSINA. Undici vigili urbani positivi al covi...
# 3564    Scoppia un un focolaio presso la struttura di ...
# 3565            Nella casa di riposo ci sono 28 positivi.
# 3566    MONTEBELLUNA - Focolaio di Covid in Chirurgia:...
# 3567    Oggi registriamo un dato di 16 casi positivi (...
# 3568    «Troppi positivi nei reparti». È questo il gri...
# 3569    Apprendiamo con preoccupazione che risultano n...
# 3570    Sono terminate le operazioni di sbarco dei mig...
# 3571    Sono 738 i detenuti positivi al Covid, un cent...
# 3572    on due, non quattro e neanche dieci. Sono una ...
# 3591    I pacchi all'antrace del 2001 erano un . L'Ame...
# 3648    Un Cluster familiare nato in un gruppo di no v...
# 3649    Mini focolaio in una famiglia di Cesa. Dopo il...
# 3650    ﻿Impennata di contagi in Irpinia, dall’ultimo ...
# 3651    Monti. Piccolo focolaio Covid-19 a Monti! Il n...
# 3652    Il virus torna nelle case di riposo. Nelle ult...
# 3653    Focolaio di coronavirus alla casa di riposo Me...
# 3654    Un focolaio di contagi è esploso in una Rsa di...
# 3655    A Canosa di Puglia, nella Bat, nella struttura...
# 3656    40 persone positive tra cui 10 in una casa di ...
# 3657    CARPI (Modena) – L’Ospedale Ramazzini di Carpi...
# 3658    Un piccolo focolaio di contagi da Covid si è v...
# 3659    Dieci operatori sanitari vaccinati, tra inferm...
# 3660    TREVISO. L’Ulss 2 della Marca Trevigiana deve ...
# 3661    Focolaio all’aeroporto Marco Polo di Venezia. ...
# 3662    Focolaio di Covid-19 al circolo ricreativo “I ...
# 3663    SCANSANO – Sono 20 i positivi al Coronavirus a...
# 3664    28 Ago 2021 Fino a sabato 21 nessuno aveva man...
# 3665    Ardea, 26 agosto 2021- In riferimento alla seg...
# 3666    Il virus entra in albergo. Accade in una strut...
# 3667    Nuovo bollettino epidemiologico dal tasso elev...
# 3668    Focolaio Covid nel popolare quartiere Fontanel...
# 3669    Il virus conferma la sua frenata in Romagna, c...
# 3670    CETONA – Il virus sembra essere in ritirata, m...
# 3671    San Bartolomeo in Galdo (Bn) – Terminerà in Da...
# 3672    Nel giorno in cui ripartono i ristoranti, anch...
# 3673    Positivi al coronavirus, paucisintomatici e co...
# 3674    ACRI – Si allarga il focolaio del contagio nel...
# 3675    Le persone risultate positive al Covid19 resid...
# 3676    CAPOLIVERI. Da una parte il virus che “sbarca”...
# 3677    GROSSETO – Sono 26 i nuovi casi di coronavirus...
# 3678    Dopo due settimane consecutive durante le qual...
# 3679    Sono saliti ad oltre 25 i casi positivi nel co...
# 3680    "Nell'istituto foggiano resta il focolaio più ...
# 3681    ....lo scorso 4 giugno è iniziata la risalita ...
# 3682    Il virus è tornato crescere e a correre, forte...
# 3683    ....I suoi effetti non si notano soltanto negl...
# 3684    Cresce anche a Brindisi la paura per un massic...
# 3685    ...Tornano i focolai all'Azienda ospedaliera M...
# 3686    Cluster positivo nel cast. L’appuntamento del ...
# 3687    I primi casi si sono verificati pochi giorni d...
# 3688    ...In un’azienda sulmonese si è aperto ufficia...
# 3689    Un compleanno a Oulx e due giorni a Caorle. Un...
# 3690    Per capire meglio la diffusione del contagio d...
# 3691    Focolaio in piazza Scaravilli. Folla e poche m...
# 3692    Uno in città, l’altro a Loreto. Nuovi positivi...
# 3693    Appello per il rispetto delle misure di preven...
# 3694    Bollettino di oggi, 25 settembre, sui dati di ...
# 3695    Sono 350 i tamponi previsti in mattinata dando...
# 3696    Trentanove casi sono collegati al focolaio nel...
# 3697    Preoccupazione per il nuovo cluster individuat...
# 3698    Il Genoa ha giocato ieri al San Paolo contro i...
# 3699    Coronavirus, focolaio in una ditta di Forlì: i...
# 3700    Alcuni dipendenti della Nuova FoodItalia sono ...
# 3701    Coronavirus: gita in Sicilia, focolaio nel Chi...
# 3702    Il Covid entra nelle scuole friulane. Studenti...
# 3703    L’ondata di contagi primaverile sembra finalme...
# 3704    Focolaio Covid alle scuole elementari San Gemi...
# 3705    Viene specificato nel report che "i focolai at...
# 3706    Didattica a distanza per ora fino al 15 Maggio...
# 3707    Cinquanta casi positivi su settanta giovani. L...
# 3708    “In base alla comunicazione della Asl Roma 4 p...
# 3709    Il virus continua a colpire tra i giovani. Tan...
# 3710    “Avendo avuto comunicazione di positività Covi...
# 3711    Preoccupazione dei genitori per una nota invia...
# 3712    ...   Scuole chiuse  L’incubo del Covid19 è to...
# 3713    Un inspiegabile ritardo nella somministrazione...
# 3714    Alcuni pazienti della comunità riabilitativa e...
# 3715    AOSTA. Un cluster Covid è emerso nella casa pe...
# 3716    Diversi casi di positività al Covid sono stati...
# 3717    ...Queste le parole del direttore generale del...
# 3718    In Alto Sangro si sarebbe acceso un nuovo foco...
# 3719    CATANIA – Registrato un cluster di Covid 19 al...
# 3720    Ciò si è reso necessario in quanto le autorità...
# 3721    La nave è rimasta lontano dal porto e i medici...
# 3722    Crescono i contagi in provincia dell’Aquila: i...
# 3723    Il bilancio dell’ultima settimana a Bellizzi, ...
# 3724    Gallipoli – Un focolaio in una struttura balne...
# 3725    Sono quasi tutti asintomatici, 15 anziani rico...
# 3726    Due aule e un corridoio diventate «zona rossa»...
# 3727    Per il territorio provinciale di Ravenna oggi ...
# 3728    Sono solo 5 le guarigioni definitive. Fra i ca...
# 3729    Nei giorni scorsi sono stati ospiti di una str...
# 3730    Un focolaio in provincia di Taranto riguarda R...
# 3731    A Salemi salgono a 7 i positivi al Coronavirus...
# 3732    Uno dei nuovi positivi rispetto a 24 ore fa è ...
# 3733    Un focolaio Covid costringe alla quarantena l’...
# 3734    .... Contagi a raffica tra i bambini. Ad Andre...
# 3735    Sono più di 40 gli ospiti di due Rsa risultati...
# 3736    CORMONS Un focolaio di Covid è stato individua...
# 3737    Focolaio Covid-19 alla residenza protetta Bald...
# 3738    Al secondo piano della residenza sanitaria ass...
# 3739    RIETI - Focolaio Covid in una Rsa della Sabina...
# 3740    A preoccupare è il focolaio esploso nella RSA ...
# 3741    Sono 28 i contagi da Covid-19 riscontrati in u...
# 3742    Torna l’incubo Covid nelle residenze per anzia...
# 3743    Sette i casi riscontrati tra i ricoverati, asi...
# 3744    Un piccolo focolaio di Covid-19 è scoppiato ne...
# 3745    Una ventina gli operatori sanitari coinvolti n...
# 3746    Torna l’incubo virus all’Umberto I: scoperti q...
# 3747    ...   Come riporta la Gazzetta del Sud, infatt...
# 3748    Oggi la sottovariante della mutazione sudafric...
# 3749    Positivi al Covid ma ricoverati nella stessa s...
# 3750    La Sicilia è in zona bianca ma spuntano nuovi ...
# 3751    Oltre venti positivi tra i giovanissimi pazien...
# 3752    Focolaio ai vertici del Pirellone. Dopo il gov...
# 3753    Quattro atlete e il coach Matassini positivi, ...
# 3754    Niente da fare, arriva a distanza di molte set...
# 3755    ...   Nelle ultime ore un nuovo focolaio è div...
# 3756    Si espande il focolaio Covid in casa Avellino:...
# 3757    Il Covid19 arriva ad Ustica, piccola isola nel...
# 3758    L'incontro, originariamente in programma domen...
# 3759    Focolaio-Covid nello spogliatoio del Cus Cagli...
# 3769    SANTA LUCIA DI PIAVE - Salgono i contagi alla ...
# 3775    MINTURNO – E’ stato confermato un cluster epid...
# 3784    Il bilancio del focolaio scoppiato nella rssa ...
# 3810    In Romagna il contagio covid sempre essersi st...
# 3811    A casa cinque magistrati e una quindicina di d...
# 3812    Contagiati quattro dipendenti nella sede di an...
# 3813    ... "Apprendiamo che su 34 ragazzi presenti al...
# 3814    Sei pazienti risultati positivi. Non possiamo ...
# 3815    Una cena di Natale: quindici parenti. Tutti va...
# 3816    Scoperto un focolaio di rientro da una vacanza...
# 3817    Nella casa di riposo Jb Festaz di Aosta è emer...
# 3818    ...Si allarga il focolaio all’Iras di Rovigo n...
# 3819    A Rimini i focolai nelle Rsa, nel periodo 27 d...
# 3820    ...Il focolaio in corso nella RSA D. Beccafumi...
# 3821    Il virus torna a far irruzione nelle case di r...
# 3822    Il Covid torna dentro le case di riposo. Succe...
# 3823    Fino alla terza ondata la casa di riposo di Pe...
# 3824    Focolaio di casi positivi al Covid19 in una re...
# 3825    La famigerata variante Omicron non ha risparmi...
# 3826    Proprio come si sta verificando all'ospedale S...
# 3827    Focolaio nell'ospedale "Vito Fazzi" di Lecce, ...
# 3828    Focolai Covid negli ospedali palermitani: ci s...
# 3829    L'Asl Città di Torino, dopo avere constatato u...
# 3830    ...Il Covid 19 sta letteralmente falcidiando i...
# 3831    ...... il Mantova che sta comunicando il ciclo...
# 3832    Cluster rossonero Covid: ma con la Roma si gio...
# 3833    Focolaio Covid per il Verona, con gara di La S...
# 3834    Questo il comunicato diffuso dalla società pat...
# 3835    Focolaio Covid anche all'Udinese: la società f...
# 3836    Giù il sipario al Carlo Felice sull'apertura d...
# 3837    Salgono a 8 le positività in casa Bologna. Dop...
# 3838    Con una nota ufficiale, il Fiorenzuola fa sape...
# 3839    L’olandese Nils Klapwijk, anche lui risultato ...
# 3840    La Igor Novara non avrà, come magari si augura...
# 3841    Il cluster Covid che si è sviluppato all’inter...
# 3842    Il cluster Covid scoppiato nel gruppo squadra ...
# 3843    Un incremento di casi positivi del 17 per cent...
# 3844    Dopo la positività di mister Spugna al Covid, ...
# 3845    Tre contagi Covid nel giro di pochi giorni all...
# 3846    “Focolaio Covid19 con 7 positivi al dormitorio...
# 3847    ...ad Angri, gli uffici comunali sono chiusi a...
# 3848    Poco più di un anno dopo, sembra essere tornat...
# 3849    Un'emergenza senza fine: il focolaio da Covid-...
# 3850    La Salernitana rischia di affrontare in totale...
# 3851    ...Diversi sono, intanto, i focolai che si reg...
# 3852    La società ha reso noto che dopo lo screening ...
# 3853    Sono una quarantina i bambini in quarantena do...
# 3854    Trenta studenti positivi al Covid in sette cla...
# 3855    Apochi giorni dall'inizio delle scuole, a Russ...
# 3856    ...Complessivamente sono dieci le sezioni in q...
# 3857    ...A Trapani però c’è già un piccolo focolaio....
# 3858    ....nell’Astigiano si registra infatti anche l...
# 3859    E’ allarme a Lecce per un focolaio Covid divam...
# 3860    Dopo quello dell’Istituto Padri Trinitari, un ...
# 3861    ..."In merito alla segnalazione di alcuni casi...
# 3862    VIGEVANO (Pavia) La scoperta di un cluster all...
# 3863    .... Preoccupano però due giovani future mamme...
# 3864    Tre suore del convento di Santa Marta, a Venti...
# 3865    ....Il ricevimento si è tenuto una decina di g...
# 3866    TRENTO. Erano andati a Rimini per qualche gior...
# 3867    RIETI - Cinque bambini, di cui tre appartenent...
# 3868    Il  focolaio di Covid 19, che ha colpito la ci...
# 3869    Platania – Ritorna l’incubo scuola-Covid. L’in...
# 3870    Allarme per un focolaio: sono 25 i positivi al...
# 3871    Residenza protetta Suarez di Calizzano – Dalle...
# 3874    Cluster ASL2 Ospedale San Paolo - Il 7 dicembr...
# 3879    ...“Stiamo tornando a vedere cluster familiari...
# 3880    ROCCASTRADA – Duo focolai in due frazioni di R...
# 3881     Nel frattempo, stanno tornando i cluster fami...
# 3882    PADOVA. Ci sono due nuovi cluster in due istit...
# 3883    Covid, il contagio viaggia veloce tra i ragazz...
# 3884    Positività iniziale di un insegnante: in isola...
# 3885    Dolceacqua. Cluster di Covid nelle scuole medi...
# 3886    ...La frontiera del virus restano al momento l...
# 3887    ﻿PIEVE DI CENTO. C’è agitazione e preoccupazio...
# 3888    ...le scuole che, come tutto il resto, risento...
# 3889    Bologna, 18 novembre 2021 - Un’intera comunità...
# 3890    Chiusa l'intera scuola media di Stia per la pr...
# 3891    VIAREGGIO. Dodici positivi al Covid, tra bambi...
# 3892    Focolaio nella scuola di Cenerente (Perugia) S...
# 3893    I positivi sono 112 e 269 in isolamento, tanti...
# 3894    L'istituto comprensivo Via Cassia 1694 è la pr...
# 3895    ...L’ultimo caso in regione riguarda Colli a V...
# 3896    ..Dei nuovi casi, 14 sono stati riscontrati a ...
# 3897    Sono 5 bambini della scuola materna, 1 delle m...
# 3898    Focolai nelle scuole e contagi in crescita a C...
# 3899    ...Il dato preoccupante riguarda la fascia gio...
# 3900    CARINI – Il sindaco di Carini, Giovì Monteleon...
# 3901    CASALE MONFERRATO. Focolaio nella casa di ripo...
# 3902    Arma di Taggia. Focolaio covid tra gli ospiti ...
# 3903    Gli anziani ospiti non presentano alcuna sinto...
# 3904    Focolaio da Covid in una struttura per anziani...
# 3905    Premilcuore (Forlì-Cesena), 19 novembre 2021 –...
# 3906    Scattati tutti i protocolli di sicurezza alla ...
# 3907    Quattro morti e diversi contagiati di covid. E...
# 3908    Le vittime sono due uomini di 78 e 89 anni, de...
# 3909    Latina – Il cluster da Covid-19 nella casa di ...
# 3910    Torna l’emergenza Covid nelle scuole. A Santa ...
# 3911    ...un focolaio con 14 positivi (su 22 ospiti) ...
# 3912    All'ospedale Cardinal Massaia di Asti dieci pa...
# 3913    I pazienti risultati positivi al Covid li hann...
# 3914    ROVIGO - Durante l’esecuzione di un ulteriore ...
# 3915    (ANSA) - GENOVA, 22 NOV - Nell'ospedale Gallie...
# 3916    Mini focolaio nel reparto di Medicina interna ...
# 3917    BOSIO – Un evento gastronomico organizzato sab...
# 3918    Doppio focolaio Covid in città a Brescia segna...
# 3919    TREVISO. La quarta ondata in provincia di Trev...
# 3920      GROSSETO. Contagi più che triplicati in un g...
# 3921    È il sindaco di Castignano – Fabio Polini – a ...
# 3922    Non si ferma l'ondata di contagi al covid nel ...
# 3923    TARANTO- Cinque mesi fa il primo focolaio Covi...
# Name: news, dtype: object

# %% [markdown]
# ### Remove Duplicates ###

# %%
count = 0

for news in df['news']:
    count += 1

print(count)
# Out:
# 3924

# %%
df.duplicated().sum()
# Out:
# 498

# %%
df = df.drop_duplicates(keep="first")

# %%
count = 0

for news in df['news']:
    count += 1

print(count)
# Out:
# 3426

# %% [markdown]
# #### Check language of the news ####

# %%
total_news = 0
en_news = 0
it_news = 0
foreign_news = 0


if(news):
    for news in df['news']:
        if(detect(news) == 'en'):
            en_news += 1
            total_news += 1
            print(news)
        if(detect(news) == 'it'):
            it_news += 1
            total_news += 1   
        if(detect(news) != 'en' and detect(news) != 'it'):
            foreign_news += 1
            total_news += 1



print('Total News: ', total_news )
print('Italian News: ', it_news)
print('English News: ', en_news)
print('Foreign News: ', foreign_news)
# Out:
# Simona Granati - Corbis via Getty Images ROME, ITALY - JANUARY 31: The entrance of the National Institute for Infectious Diseases Lazzaro Spallanzani in Rome, where two Chinese tourists who tested positive for Coronavirus 2019-nCov, are kept in isolation. on January 31, 2020 in Rome, Italy.
# ---------------------------------------------------------------------------
# LangDetectException                       Traceback (most recent call last)
# Cell In[56], line 9
#       7 if(news):
#       8     for news in df['news']:
# ----> 9         if(detect(news) == 'en'):
#      10             en_news += 1
#      11             total_news += 1
#
# File ~/.local/lib/python3.10/site-packages/langdetect/detector_factory.py:130, in detect(text)
#     128 detector = _factory.create()
#     129 detector.append(text)
# --> 130 return detector.detect()
#
# File ~/.local/lib/python3.10/site-packages/langdetect/detector.py:136, in Detector.detect(self)
#     132 def detect(self):
#     133     '''Detect language of the target text and return the language name
#     134     which has the highest probability.
#     135     '''
# --> 136     probabilities = self.get_probabilities()
#     137     if probabilities:
#     138         return probabilities[0].lang
#
# File ~/.local/lib/python3.10/site-packages/langdetect/detector.py:143, in Detector.get_probabilities(self)
#     141 def get_probabilities(self):
#     142     if self.langprob is None:
# --> 143         self._detect_block()
#     144     return self._sort_probability(self.langprob)
#
# File ~/.local/lib/python3.10/site-packages/langdetect/detector.py:150, in Detector._detect_block(self)
#     148 ngrams = self._extract_ngrams()
#     149 if not ngrams:
# --> 150     raise LangDetectException(ErrorCode.CantDetectError, 'No features in text.')
#     152 self.langprob = [0.0] * len(self.langlist)
#     154 self.random.seed(self.seed)
#
# LangDetectException: No features in text.

# %% [markdown]
# Keeping just the italian ones (approx. 99.9%)

# %%
for news in df['news']:
    if(detect(news) == 'en' or detect(news) != 'it'):
        df = df.drop((df.index[df["news"]== news].tolist()))
 
total_news = 0
en_news = 0
it_news = 0
foreign_news = 0

for news in df['news']:
    if(detect(news) == 'en'):
        en_news += 1
        total_news += 1
    if(detect(news) == 'it'):
        it_news += 1
        total_news += 1   
    if(detect(news) != 'en' and detect(news) != 'it'):
        foreign_news += 1
        total_news += 1


print('Total News: ', total_news )
print('Italian News: ', it_news)
print('English News: ', en_news)
print('Foreign News: ', foreign_news)

df.reset_index(drop=True, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# LangDetectException                       Traceback (most recent call last)
# Cell In[14], line 2
#       1 for news in df['news']:
# ----> 2     if(detect(news) == 'en' or detect(news) != 'it'):
#       3         df = df.drop((df.index[df["news"]== news].tolist()))
#       5 total_news = 0
#
# File ~/.local/lib/python3.10/site-packages/langdetect/detector_factory.py:130, in detect(text)
#     128 detector = _factory.create()
#     129 detector.append(text)
# --> 130 return detector.detect()
#
# File ~/.local/lib/python3.10/site-packages/langdetect/detector.py:136, in Detector.detect(self)
#     132 def detect(self):
#     133     '''Detect language of the target text and return the language name
#     134     which has the highest probability.
#     135     '''
# --> 136     probabilities = self.get_probabilities()
#     137     if probabilities:
#     138         return probabilities[0].lang
#
# File ~/.local/lib/python3.10/site-packages/langdetect/detector.py:143, in Detector.get_probabilities(self)
#     141 def get_probabilities(self):
#     142     if self.langprob is None:
# --> 143         self._detect_block()
#     144     return self._sort_probability(self.langprob)
#
# File ~/.local/lib/python3.10/site-packages/langdetect/detector.py:150, in Detector._detect_block(self)
#     148 ngrams = self._extract_ngrams()
#     149 if not ngrams:
# --> 150     raise LangDetectException(ErrorCode.CantDetectError, 'No features in text.')
#     152 self.langprob = [0.0] * len(self.langlist)
#     154 self.random.seed(self.seed)
#
# LangDetectException: No features in text.

# %% [markdown]
# #### Check how the categories are distributed ####

# %%
categories_list = (df['category'].unique())
counter = {}

for category in df['category']:
    if category not in counter:
        counter[category] = 0
    counter[category] += 1

hist_categories_x = list(counter.keys())
hist_categories_y = list(counter.values())

fig = plt.figure(figsize = (15, 8))

plt.bar(hist_categories_x, hist_categories_y, color =['green','red','blue','black','orange','purple', 'brown', 'cyan'], aa=True, width = 0.2)
plt.xlabel("Categories")
plt.ylabel("No. of news")
plt.xticks(rotation = 'vertical')
xlocs, xlabs = plt.xticks()
xlocs=[i+1 for i in range(0,len(categories_list))]
xlabs=[i/2 for i in range(0,len(categories_list))]
for i, v in enumerate(hist_categories_y):
    if(v > 99 and v < 1000):
        plt.text(xlocs[i] - 1.155, v + 13, str(v), fontweight="bold")
    elif(v > 9 and v < 100):
        plt.text(xlocs[i] - 1.12, v + 13, str(v), fontweight="bold")
    elif(v > 0 and v < 10):
        plt.text(xlocs[i] - 1.06, v + 13, str(v), fontweight="bold")

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Categories Cleaning ###

# %% [markdown]
# #### Re-instance ####

# %%
row_count = 0
for category in df['category']:
    if category == 'Coronavirus - Focolai familiari':
        df.loc[row_count, 'category'] = 'Coronavirus - Focolai familiari/amici'
    row_count += 1

# %%
row_count = 0
for category in df['category']:
    if category == 'Coronavirus - Focoali RSA/Case di riposo':
        df.loc[row_count, 'category'] = 'Coronavirus - Focolai RSA/Case di riposo'
    row_count += 1

# %%
row_count = 0
for category in df['category']:
    if category == 'Coronavirus - VARIANTE INGLESE':
        df.loc[row_count, 'category'] = 'Coronavirus - VARIANTI'
    row_count += 1

# %% [markdown]
# #### Drop of the not useful categories according to the ISS ####

# %%
df.drop(df[df.category == 'Zone Rosse'].index, inplace=True)
df.drop(df[df.category == 'Malattie a trasmissione interumana diretta'].index, inplace=True)
df.drop(df[df.category == '2019-nCoV'].index, inplace=True)
df.drop(df[df.category == 'SARS-CoV-2'].index, inplace=True)
df.drop(df[df.category == 'Malattie con altro tipo di trasmissione'].index, inplace=True)
df.drop(df[df.category == 'Malattie a trasmissione ambientale'].index, inplace=True)
df.drop(df[df.category == 'Malattie a trasmissione oro-fecale'].index, inplace=True)

# %%
categories_list = (df['category'].unique())
counter = {}

for category in df['category']:
    if category not in counter:
        counter[category] = 0
    counter[category] += 1

hist_categories_x = list(counter.keys())
hist_categories_y = list(counter.values())

fig = plt.figure(figsize = (15, 8))

plt.bar(hist_categories_x, hist_categories_y, color =['green','red','blue','black','orange','purple', 'brown', 'cyan'], aa=True, width = 0.2)
plt.xlabel("Categories")
plt.ylabel("No. of news")
plt.xticks(rotation = 'vertical')
xlocs, xlabs = plt.xticks()
xlocs=[i+1 for i in range(0,len(categories_list))]
xlabs=[i/2 for i in range(0,len(categories_list))]
for i, v in enumerate(hist_categories_y):
    if(v > 99 and v < 1000):
        plt.text(xlocs[i] - 1.06, v + 13, str(v), fontweight="bold")
    elif(v > 9 and v < 100):
        plt.text(xlocs[i] - 1.12, v + 13, str(v), fontweight="bold")
    elif(v > 0 and v < 10):
        plt.text(xlocs[i] - 1.06, v + 13, str(v), fontweight="bold")

plt.tight_layout()

plt.show()

# %%
df.shape
# Out:
# (3263, 4)

# %% [markdown]
# ### Text Cleaning ###

# %%
df['category_id'] = df['category'].factorize()[0]
for element1, element2 in zip(df['category'].unique(), df['category_id'].unique()):
    print(element1 , '-->' , element2)
# Out:
# Coronavirus - VARIANTI --> 0
# Coronavirus - Focolai scolastico --> 1
# Coronavirus - Focolai in altri contesti --> 2
# Coronavirus - Focolai familiari/amici --> 3
# Coronavirus - Focolai RSA/Case di riposo --> 4
# Coronavirus - VARIANTE INGLESE --> 5
# Coronavirus - Focolai familiari --> 6
# Coronavirus - Focoali RSA/Case di riposo --> 7
# Coronavirus - Focolai ospedalieri --> 8

# %%
{k: v for k, v in sorted(counter.items(), reverse=True, key=lambda item: item[1])}
# Out:
# {'Coronavirus - Focolai in altri contesti': 948,
#  'Coronavirus - Focolai RSA/Case di riposo': 683,
#  'Coronavirus - Focolai scolastico': 568,
#  'Coronavirus - Focolai ospedalieri': 420,
#  'Coronavirus - VARIANTI': 313,
#  'Coronavirus - Focolai familiari/amici': 296,
#  'Coronavirus - Focolai familiari': 19,
#  'Coronavirus - VARIANTE INGLESE': 12,
#  'Coronavirus - Focoali RSA/Case di riposo': 4}

# %%
pd.set_option('display.max_colwidth', None)
df.iloc[233, 2:3]
# Out:
# news    Il Covid torna a mandare in apprensione il calcio italiano, l’annuncio circa la positività al Coronavirus gela i tifosi. È un ex calciatore a rivelare gli ultimi rumors, sulle indiscrezioni legate al problema Covid in Nazionale. Il gruppo squadra sarebbe colpito da un vero e proprio focolaio.
# Name: 386, dtype: object

# %%
def remove_tags(text):
  remove = re.compile(r'')
  return re.sub(remove, '', str(text))
  
df['news'] = df['news'].apply(remove_tags)

def special_char(text):
  reviews = ''
  for x in text:
    if x.isalnum():
      reviews = reviews + x
    else:
      reviews = reviews + ' '
  return reviews
  
df['news'] = df['news'].apply(special_char)

def convert_lower(text):
   return text.lower()

df['news'] = df['news'].apply(convert_lower)

def remove_stopwords(text):
  stop_words = set(stopwords.words('english'))
  words = word_tokenize(text)
  return [x for x in words if x not in stop_words]
  
df['news'] = df['news'].apply(remove_stopwords)


def lemmatize_word(text):
  wordnet = WordNetLemmatizer()
  return " ".join([wordnet.lemmatize(word) for word in text])

df['news'] = df['news'].apply(lemmatize_word)

# %%
df.iloc[233, 2:3]
# Out:
# news    coronavirus la variante inglese è arrivata pisa potrebbe essere arrivata pisa la cosiddetta variante inglese del covid 19 la notizia è riportata dai quotidiani locali anche se la conferma deve arrivare dalle analisi di laboratorio che verranno eseguite ospedale cisanello nei prossimi giorni
# Name: 356, dtype: object

# %% [markdown]
# ### Learning ###

# %%
from sklearn.feature_extraction.text import CountVectorizer
x = np.array(df['news'])
y = np.array(df['category_id'])
cv = CountVectorizer()
x = cv.fit_transform(x).toarray()
print("X.shape = ",x.shape)
print("y.shape = ",y.shape)
# Out:
# X.shape =  (3245, 15933)
# y.shape =  (3245,)

# %% [markdown]
# ##### Define the k "best" for CV #####

# %%
model1 = LogisticRegression(max_iter=400)
 
# evaluate the model using a given test condition
def evaluate_model(cv):
	
	# evaluate the model
	scores = cross_val_score(model1, x, y, scoring='accuracy', cv=cv, n_jobs=-1)
	# return scores
	return mean(scores), scores.min(), scores.max()
 
# calculate the ideal test condition
ideal, _, _ = evaluate_model(LeaveOneOut())
print('Ideal: %.3f' % ideal)
# define folds to test
folds = range(2,16)
# record mean and min/max of each set of results
means, mins, maxs = list(),list(),list()
# evaluate each k value
for k in folds:
	# define the test condition
	cv = KFold(n_splits=k, shuffle=True, random_state=1)
	# evaluate k value
	k_mean, k_min, k_max = evaluate_model(cv)
	# report performance
	print('> folds=%d, accuracy=%.3f (%.3f,%.3f)' % (k, k_mean, k_min, k_max))
	# store mean accuracy
	means.append(k_mean)
	# store min and max relative to the mean
	mins.append(k_mean - k_min)
	maxs.append(k_max - k_mean)
# line plot of k mean values with min/max error bars
plt.errorbar(folds, means, yerr=[mins, maxs], fmt='o')
# plot the ideal case in a separate color
plt.plot(folds, [ideal for _ in range(len(folds))], color='r')
# show the plot
plt.show()
# Out:
# Ideal: 0.805
# > folds=2, accuracy=0.777 (0.774,0.779)
# > folds=3, accuracy=0.786 (0.775,0.806)
# > folds=4, accuracy=0.796 (0.788,0.803)
# > folds=5, accuracy=0.792 (0.767,0.818)
# > folds=6, accuracy=0.795 (0.776,0.830)
# > folds=7, accuracy=0.798 (0.774,0.825)
# > folds=8, accuracy=0.798 (0.770,0.833)
# > folds=9, accuracy=0.795 (0.762,0.828)
# > folds=10, accuracy=0.798 (0.759,0.846)
# > folds=11, accuracy=0.798 (0.749,0.837)
# > folds=12, accuracy=0.798 (0.759,0.856)
# > folds=13, accuracy=0.798 (0.751,0.844)
# > folds=14, accuracy=0.799 (0.740,0.836)
# > folds=15, accuracy=0.798 (0.750,0.848)

# %% [markdown]
# #### Split and Folds ####

# %%
folds = KFold(n_splits = 4, shuffle = True)
y_bin = label_binarize(y, classes=range(len(categories_list)))
x_train, x_test, y_train, y_test = train_test_split(x, y_bin, test_size = 0.30, random_state = 9)

# %% [markdown]
# #### Useful Functions For Evaluation ####

# %%
def evaluate(target, prediction):

    accuracy = round(metrics.accuracy_score(target, prediction) * 100, 2)
    precision = round(metrics.precision_score(target, prediction, average='micro') * 100, 2)
    recall = round(metrics.recall_score(target, prediction, average='micro') * 100, 2)
    f1_score = round(metrics.f1_score(target ,prediction, average='micro') * 100, 2)

    confusion_matrix = metrics.confusion_matrix(target.argmax(axis=1), prediction.argmax(axis=1))

    print('Confusion Matrix\n')

    for row in range(len(confusion_matrix)):
        print(categories_list[row]+"\t"+str(confusion_matrix[row]))

    print('\n')

    print('\nClassification Report\n')
    print(classification_report(target, prediction, target_names=categories_list))
    print('Accuracy : ' ,accuracy)

# %%
def drawROC(score):
    # Compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(len(categories_list)):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], score[:, i])
        roc_auc[i] = metrics.auc(fpr[i], tpr[i])

    # Plot of a ROC curve for a specific class
    for i in range(len(categories_list)):
        plt.figure()
        plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % roc_auc[i])
        plt.plot([0, 1], [0, 1], 'k--')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('ROC Curve Class: ' + categories_list[i])
        plt.legend(loc="lower right")
        plt.show()

# %% [markdown]
# ### Baseline (Logistic Regression) ####

# %%
mdl1 = LogisticRegression(multi_class='ovr', solver='lbfgs', max_iter=400)
clf_1 = OneVsRestClassifier(mdl1)

clf_1.fit(x_train, y_train)
y_pred = clf_1.predict(x_test)

evaluate(y_test, y_pred)
# Out:
# Confusion Matrix
#
# Coronavirus - VARIANTI	[104   3   6   0   0   0]
# Coronavirus - Focolai scolastico	[ 38 123  11   3   0   0]
# Coronavirus - Focolai in altri contesti	[ 59   5 200   9   2   1]
# Coronavirus - Focolai familiari/amici	[28  6 23 17  1  0]
# Coronavirus - Focolai RSA/Case di riposo	[ 30   2   8   1 152   3]
# Coronavirus - Focolai ospedalieri	[20  0 18  0  5 96]
#
#
#
# Classification Report
#
#                                           precision    recall  f1-score   support
#
#                   Coronavirus - VARIANTI       0.90      0.79      0.84       113
#         Coronavirus - Focolai scolastico       0.89      0.72      0.79       175
#  Coronavirus - Focolai in altri contesti       0.72      0.72      0.72       276
#    Coronavirus - Focolai familiari/amici       0.57      0.32      0.41        75
# Coronavirus - Focolai RSA/Case di riposo       0.93      0.79      0.86       196
#        Coronavirus - Focolai ospedalieri       0.96      0.73      0.83       139
#
#                                micro avg       0.84      0.71      0.77       974
#                                macro avg       0.83      0.68      0.74       974
#                             weighted avg       0.84      0.71      0.77       974
#                              samples avg       0.70      0.71      0.70       974
#
# Accuracy :  68.07
# /home/paoloc/.local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_score_lr = clf_1.fit(x_train, y_train).decision_function(x_test)

drawROC(y_score_lr)

# %% [markdown]
# ### Gradient Boosting ###

# %% [markdown]
# #### Tuning ####

# %%
scores_boost = []

r = [5, 15, 25, 50, 75,  100, 150, 200]
for k in r:
    score_boost = cross_val_score(estimator=GradientBoostingClassifier(n_estimators=k), X = x, y= y, cv=folds, scoring='accuracy')
    scores_boost.append(score_boost.mean())

# %%
fig = plt.figure(figsize=(14,6))
ax = fig.gca()
plt.plot(r, scores_boost, marker='o') 
plt.xlabel(r'Numero di stimatori')
plt.ylabel('Score')
plt.title(r'Score al variare del numero di stimatori')
plt.show()

# %%
gbc = GradientBoostingClassifier(n_estimators=125)
parameters = {
    "max_depth":[3,5,7],
    "learning_rate":[0.01,0.1,1]
}

# %%
from sklearn.model_selection import GridSearchCV
cv = GridSearchCV(gbc,parameters,cv=folds)
cv.fit(x,y)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#              estimator=GradientBoostingClassifier(n_estimators=125),
#              param_grid={'learning_rate': [0.01, 0.1, 1],
#                          'max_depth': [3, 5, 7]})

# %%
def display(results):
    print(f'Best parameters are: {results.best_params_}')
    print("\n")
    mean_score = results.cv_results_['mean_test_score']
    std_score = results.cv_results_['std_test_score']
    params = results.cv_results_['params']
    for mean,std,params in zip(mean_score,std_score,params):
        print(f'{round(mean,3)} + or -{round(std,3)} for the {params}')

# %%
display(cv)
# Out:
# Best parameters are: {'learning_rate': 0.1, 'max_depth': 3}
#
#
# 0.773 + or -0.016 for the {'learning_rate': 0.01, 'max_depth': 3}
# 0.78 + or -0.008 for the {'learning_rate': 0.01, 'max_depth': 5}
# 0.776 + or -0.01 for the {'learning_rate': 0.01, 'max_depth': 7}
# 0.802 + or -0.01 for the {'learning_rate': 0.1, 'max_depth': 3}
# 0.801 + or -0.013 for the {'learning_rate': 0.1, 'max_depth': 5}
# 0.791 + or -0.01 for the {'learning_rate': 0.1, 'max_depth': 7}
# 0.743 + or -0.012 for the {'learning_rate': 1, 'max_depth': 3}
# 0.765 + or -0.003 for the {'learning_rate': 1, 'max_depth': 5}
# 0.775 + or -0.015 for the {'learning_rate': 1, 'max_depth': 7}

# %% [markdown]
# #### Learning ####

# %%
mdl2 = GradientBoostingClassifier(n_estimators=125, learning_rate=0.1, max_depth=3)
clf_2 = OneVsRestClassifier(mdl2) 

clf_2.fit(x_train, y_train)
y_pred = clf_2.predict(x_test)

evaluate(y_test, y_pred)
# Out:
# Confusion Matrix
#
# Coronavirus - VARIANTI	[108   2   1   2   0   0]
# Coronavirus - Focolai scolastico	[ 53 118   2   1   1   0]
# Coronavirus - Focolai in altri contesti	[108   9 153   4   1   1]
# Coronavirus - Focolai familiari/amici	[45  7  9 13  1  0]
# Coronavirus - Focolai RSA/Case di riposo	[ 25   2   2   2 163   2]
# Coronavirus - Focolai ospedalieri	[ 32   0   2   0   5 100]
#
#
#
# Classification Report
#
#                                           precision    recall  f1-score   support
#
#                   Coronavirus - VARIANTI       0.78      0.81      0.80       113
#         Coronavirus - Focolai scolastico       0.84      0.73      0.78       175
#  Coronavirus - Focolai in altri contesti       0.90      0.56      0.69       276
#    Coronavirus - Focolai familiari/amici       0.44      0.20      0.28        75
# Coronavirus - Focolai RSA/Case di riposo       0.93      0.86      0.89       196
#        Coronavirus - Focolai ospedalieri       0.93      0.73      0.82       139
#
#                                micro avg       0.86      0.68      0.76       974
#                                macro avg       0.80      0.65      0.71       974
#                             weighted avg       0.85      0.68      0.75       974
#                              samples avg       0.66      0.68      0.66       974
#
# Accuracy :  63.35
# /home/paoloc/.local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_score_gb = clf_2.fit(x_train, y_train).decision_function(x_test)
drawROC(y_score_gb)

# %% [markdown]
# #### Multinomial Naive Bayes ####

# %% [markdown]
# #### Tuning ####

# %%
np.logspace(0,-9, num=10)
from sklearn.model_selection import RepeatedStratifiedKFold

cv_method = RepeatedStratifiedKFold(n_splits=4, 
                                    n_repeats=3)

params_NB = {'alpha': np.logspace(0,-9, num=100)}

gs_NB = GridSearchCV(estimator=MultinomialNB(), 
                     param_grid=params_NB, 
                     cv=cv_method,
                     verbose=1, 
                     scoring='accuracy')


gs_NB.fit(x,y)
# Out:
# Fitting 12 folds for each of 100 candidates, totalling 1200 fits
# GridSearchCV(cv=RepeatedStratifiedKFold(n_repeats=3, n_splits=4, random_state=None),
#              estimator=MultinomialNB(),
#              param_grid={'alpha': array([1.00000000e+00, 8.11130831e-01, 6.57933225e-01, 5.33669923e-01,
#        4.32876128e-01, 3.51119173e-01, 2.84803587e-01, 2.31012970e-01,
#        1.87381742e-01, 1.51991108e-01, 1.23284674e-01, 1.00000000e-01,
#        8.11130831e-02, 6.57933225e-02, 5.336...
#        1.23284674e-07, 1.00000000e-07, 8.11130831e-08, 6.57933225e-08,
#        5.33669923e-08, 4.32876128e-08, 3.51119173e-08, 2.84803587e-08,
#        2.31012970e-08, 1.87381742e-08, 1.51991108e-08, 1.23284674e-08,
#        1.00000000e-08, 8.11130831e-09, 6.57933225e-09, 5.33669923e-09,
#        4.32876128e-09, 3.51119173e-09, 2.84803587e-09, 2.31012970e-09,
#        1.87381742e-09, 1.51991108e-09, 1.23284674e-09, 1.00000000e-09])},
#              scoring='accuracy', verbose=1)

# %%
gs_NB.best_params_
# Out:
# {'alpha': 0.2848035868435802}

# %% [markdown]
# #### Learning ####

# %%
mdl3 = MultinomialNB(alpha = 0.2848035868435802)
clf_3 = OneVsRestClassifier(mdl3) 

clf_3.fit(x_train, y_train)
y_pred = clf_3.predict(x_test)

evaluate(y_test, y_pred)
# Out:
# Confusion Matrix
#
# Coronavirus - VARIANTI	[106   4   2   1   0   0]
# Coronavirus - Focolai scolastico	[ 18 149   5   2   1   0]
# Coronavirus - Focolai in altri contesti	[ 28  31 195   8  12   2]
# Coronavirus - Focolai familiari/amici	[20 14 27 12  2  0]
# Coronavirus - Focolai RSA/Case di riposo	[  9   2  10   4 170   1]
# Coronavirus - Focolai ospedalieri	[ 7  0  5  0 33 94]
#
#
#
# Classification Report
#
#                                           precision    recall  f1-score   support
#
#                   Coronavirus - VARIANTI       0.77      0.85      0.81       113
#         Coronavirus - Focolai scolastico       0.74      0.85      0.79       175
#  Coronavirus - Focolai in altri contesti       0.76      0.79      0.77       276
#    Coronavirus - Focolai familiari/amici       0.36      0.51      0.42        75
# Coronavirus - Focolai RSA/Case di riposo       0.70      0.92      0.80       196
#        Coronavirus - Focolai ospedalieri       0.74      0.86      0.80       139
#
#                                micro avg       0.71      0.82      0.76       974
#                                macro avg       0.68      0.80      0.73       974
#                             weighted avg       0.71      0.82      0.76       974
#                              samples avg       0.73      0.82      0.76       974
#
# Accuracy :  65.71
# /home/paoloc/.local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
Y_gnb_score = clf_3.predict_proba(x_test)
drawROC(Y_gnb_score)
